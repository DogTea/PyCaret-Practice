# %% [markdown]
# ### Anomaly Detection pycaret
# https://pycaret.org/anomaly-detection/

# %% [markdown]
# #import the dataset from pycaret repository
#
# from pycaret.datasets import get_data
# anomaly = get_data('anomaly')
#
# #import anomaly detection module
# from pycaret.anomaly import *
#
# #intialize the setup
# exp_ano = setup(anomaly)

# %% [markdown]
# ### For K-mean clustering, linear regression or logical regression, turn 'normalize' to 'default = true' ;
# normalize: bool, default = False
# When set to True, the feature space is transformed using the normalized_method param. Generally, linear algorithms perform better with normalized data however,  the results may vary and it is advised to run multiple experiments to evaluate the benefit of normalization.

# %% [markdown]
# # PyCaret In Depth Discussion

# %%
## moez li is a author of pycaret.
## check https://pycaret.org/ regarding tutorials: beginner and intermediate
# if you have time check Natural language processing
## check functions : model training.. model deployment.

# %%
### Created New Environment 
### installed pyCaret Library

# %%
### loading Dataset From Pycaret
from pycaret.datasets import get_data

# %%
diabetes_df= get_data('diabetes')
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
# ...

# %%
diabetes_df['Class variable'].value_counts()
## un missing value is more than half of, then its ok.
# Out:
# 0    500
# 1    268
# Name: Class variable, dtype: int64

# %% [markdown]
# # processing of supervised learning
# ## setup-compare-create-tune- plot

# %%
from pycaret.classification import*
clf=setup(data=diabetes_df,target='Class variable')
# after 'enter' will show detail
# Out:
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_8d3b6806_1519_11eb_af63_c37852971a0e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8d3b6806_1519_11eb_af63_c37852971a0elevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_8d3b6806_1519_11eb_af63_c37852971a0erow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_8d3b6806_1519_11eb_af63_c37852971a0erow0_col1" class="data row0 col1" >4082</td>
#             </tr>
#             <tr>
#                         <th id="T_8d3b6806_1519_11eb_af63_c37852971a0elevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_8d3b6806_1519_11eb_af63_c37852971a0erow1_col0" class="data row1 col0" >Target Type</td>
# ...

# %%
#### Comparing models 
compare_models()
# Out:
# <style  type="text/css" >
#     #T_a55a941e_1519_11eb_b304_c37852971a0e th {
#           text-align: left;
# ...

# %%
## because i havent changed any parameters 
## in normalize or missing values.clf=setup(data=diabetes_df,target='Class variable')
## so i couldnt say models selected by pycaret is the best one.

# %% [markdown]
# ### Regression Problem

# %%
bot_df = get_data('boston')
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
from pycaret.regression import*

# %%
reg_df=setup(data=bot_df,target='medv')
# Out:
#
# Setup Succesfully Completed.
# <style  type="text/css" >
# </style><table id="T_d12ff62c_1519_11eb_96a5_c37852971a0e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d12ff62c_1519_11eb_96a5_c37852971a0elevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d12ff62c_1519_11eb_96a5_c37852971a0erow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_d12ff62c_1519_11eb_96a5_c37852971a0erow0_col1" class="data row0 col1" >8285</td>
#             </tr>
#             <tr>
#                         <th id="T_d12ff62c_1519_11eb_96a5_c37852971a0elevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_d12ff62c_1519_11eb_96a5_c37852971a0erow1_col0" class="data row1 col0" >Transform Target </td>
# ...

# %%
#### Comparing models to find the best model
compare_models()
# Out:
# <style  type="text/css" >
#     #T_fc622a66_1519_11eb_bf8e_c37852971a0e th {
#           text-align: left;
# ...

# %% [markdown]
# https://pycaret.org/create-model/
# ### create regression model

# %%
reg_model=create_model('catboost')
# Out:
# <style  type="text/css" >
# #T_0bd3e618_151a_11eb_bd11_c37852971a0erow10_col0,#T_0bd3e618_151a_11eb_bd11_c37852971a0erow10_col1,#T_0bd3e618_151a_11eb_bd11_c37852971a0erow10_col2,#T_0bd3e618_151a_11eb_bd11_c37852971a0erow10_col3,#T_0bd3e618_151a_11eb_bd11_c37852971a0erow10_col4,#T_0bd3e618_151a_11eb_bd11_c37852971a0erow10_col5{
#             background:  yellow;
#         }</style><table id="T_0bd3e618_151a_11eb_bd11_c37852971a0e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0bd3e618_151a_11eb_bd11_c37852971a0elevel0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
### Hyper Tuning of Model, variables of created name not algothems 
reg_model_hypertune=tune_model(reg_model,n_iter=50,optimize ='MAE')
# Out:
# <style  type="text/css" >
# #T_fb728928_151a_11eb_b4e9_c37852971a0erow10_col0,#T_fb728928_151a_11eb_b4e9_c37852971a0erow10_col1,#T_fb728928_151a_11eb_b4e9_c37852971a0erow10_col2,#T_fb728928_151a_11eb_b4e9_c37852971a0erow10_col3,#T_fb728928_151a_11eb_b4e9_c37852971a0erow10_col4,#T_fb728928_151a_11eb_b4e9_c37852971a0erow10_col5{
#             background:  yellow;
#         }</style><table id="T_fb728928_151a_11eb_b4e9_c37852971a0e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fb728928_151a_11eb_b4e9_c37852971a0elevel0_row0" class="row_heading level0 row0" >0</th>
# ...

# %% [markdown]
# # processing of unsupervised learning
# ## setup-create-assign- plot

# %% [markdown]
# ### clustering model : when we dont know where the target labels is, create this data into clustering, then to know each value belongs which clusters.

# %%
### Clustering Techniques
jewellery =get_data('jewellery')
# Out:
#    Age  Income  SpendingScore       Savings
# 0   58   77769       0.791329   6559.829923
# 1   59   81799       0.791082   5417.661426
# 2   62   74751       0.702657   9258.992965
# 3   59   74373       0.765680   7346.334504
# 4   87   17760       0.348778  16869.507130

# %% [markdown]
# ### model deployment = after finalize a model, its ready for deployment.
# ### you can deploy a model on cloud : AWS.https://pycaret.org/deploy-model/

# %%
from pycaret.clustering import*
clust_df = setup(jewellery)
# setup = data preparation;clustering using elbow method ,but 'target'.
# Out:
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_3132690a_1520_11eb_8369_c37852971a0e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3132690a_1520_11eb_8369_c37852971a0elevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3132690a_1520_11eb_8369_c37852971a0erow0_col0" class="data row0 col0" >session_id </td>
#                         <td id="T_3132690a_1520_11eb_8369_c37852971a0erow0_col1" class="data row0 col1" >1274</td>
#             </tr>
#             <tr>
#                         <th id="T_3132690a_1520_11eb_8369_c37852971a0elevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_3132690a_1520_11eb_8369_c37852971a0erow1_col0" class="data row1 col0" >Original Data </td>
# ...

# %%
# compare_models() for supervised learning
# Out:
# <style  type="text/css" >
#     #T_39b49a40_1523_11eb_98c0_c37852971a0e th {
#           text-align: left;
# ...

# %%
kmeans=create_model('kmeans')
kmeans
# https://pycaret.org/clustering/

### assign the labels to the dateframe:add 'cluster'
kmeans_df=assign_model(kmeans)
kmeans_df
# Out:
#      Age  Income  SpendingScore       Savings    Cluster
# 0     58   77769       0.791329   6559.829923  Cluster 2
# 1     59   81799       0.791082   5417.661426  Cluster 2
# 2     62   74751       0.702657   9258.992965  Cluster 2
# 3     59   74373       0.765680   7346.334504  Cluster 2
# 4     87   17760       0.348778  16869.507130  Cluster 0
# ..   ...     ...            ...           ...        ...
# 500   28  101206       0.387441  14936.775389  Cluster 1
# 501   93   19934       0.203140  17969.693769  Cluster 0
# 502   90   35297       0.355149  16091.401954  Cluster 0
# 503   91   20681       0.354679  18401.088445  Cluster 0
# 504   89   30267       0.289310  14386.351880  Cluster 0
#
# [505 rows x 5 columns]

# %%
plot_model(kmeans)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
clust_db=setup(jewellery)
# Out:
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_915c17e6_1527_11eb_8ba9_c37852971a0e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_915c17e6_1527_11eb_8ba9_c37852971a0elevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_915c17e6_1527_11eb_8ba9_c37852971a0erow0_col0" class="data row0 col0" >session_id </td>
#                         <td id="T_915c17e6_1527_11eb_8ba9_c37852971a0erow0_col1" class="data row0 col1" >2953</td>
#             </tr>
#             <tr>
#                         <th id="T_915c17e6_1527_11eb_8ba9_c37852971a0elevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_915c17e6_1527_11eb_8ba9_c37852971a0erow1_col0" class="data row1 col0" >Original Data </td>
# ...

# %%
# because Density-Based Spatial'dbscan' is a popular algorithem in Clustering.  
db=create_model('dbscan')
db
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# DBSCAN(algorithm='auto', eps=0.5, leaf_size=30, metric='euclidean',
#        metric_params=None, min_samples=5, n_jobs=-1, p=None)

# %%
db_df=assign_model(db)
db_df
# Out:
#      Age  Income  SpendingScore       Savings     Cluster
# 0     58   77769       0.791329   6559.829923  Cluster -1
# 1     59   81799       0.791082   5417.661426  Cluster -1
# 2     62   74751       0.702657   9258.992965  Cluster -1
# 3     59   74373       0.765680   7346.334504  Cluster -1
# 4     87   17760       0.348778  16869.507130  Cluster -1
# ..   ...     ...            ...           ...         ...
# 500   28  101206       0.387441  14936.775389  Cluster -1
# 501   93   19934       0.203140  17969.693769  Cluster -1
# 502   90   35297       0.355149  16091.401954  Cluster -1
# 503   91   20681       0.354679  18401.088445  Cluster -1
# 504   89   30267       0.289310  14386.351880  Cluster -1
#
# [505 rows x 5 columns]

# %%
# because lack of parameters, hence the 'db' couldnt work.
plot_model(db)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...
